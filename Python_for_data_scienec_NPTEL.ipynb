# %% [markdown]
# <a href="https://colab.research.google.com/github/Shubh-ghub/skills-introduction-to-github/blob/NPTEL-Python-for-DS-Assisgnment/Python_for_data_scienec_NPTEL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cars_data=pd.read_csv('/content/mtcars.csv', index_col=0, na_values=["??","????"])
cars_data.dropna(axis=0, inplace=True)

# %%
plt.scatter(cars_data['mpg'],cars_data['wt'],c='blue')
plt.title("Scatter Plot of Mileage Vs Weight")
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Mileage Vs Weight')

# %%
cars_data.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear     carb
# count  32.000000  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   0.406250   3.687500   2.8125
# std     1.786943   0.504016   0.498991   0.737804   1.6152
# min    14.500000   0.000000   0.000000   3.000000   1.0000
# ...

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
Dia=pd.read_csv('/content/diamond.csv', index_col=0, na_values=["??","????"])
Dia.dropna(axis=0, inplace=True)
sns.boxplot(y=Dia["price"])
# Out:
# <Axes: ylabel='price'>

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
sns.boxplot(y=coco["Company Location"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-a77f2e2a6766> in <cell line: 3>()
#       1 import seaborn as sns
#       2 from pandas.api.types import CategoricalDtype
# ----> 3 sns.boxplot(y=coco["Company Location"])
#
# NameError: name 'coco' is not defined

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
Dia=pd.read_csv('/content/diamond.csv', index_col=0, na_values=["??","????"])
Dia.dropna(axis=0, inplace=True)
sns.boxplot(x= Dia["cut"],y=Dia["price"])
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
churn=pd.read_csv('/content/churn.csv', index_col=0, na_values=["??","????"])
churn.isnull().sum()
# Out:
# customerID           0
# tenure               0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges      10
# TotalCharges        15
# gender               0
# SeniorCitizen        5
# Partner              0
# Dependents           0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Churn                0
# dtype: int64

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
coco=pd.read_csv('/content/flavors_of_cocoa.csv', index_col=0, na_values=["??","????"])
coco.isnull().sum()
# Out:
# Company             0
# Bean Origin         0
# Review Date         4
# Cocoa Percent       0
# Company Location    0
# Rating              0
# dtype: int64

# %%
coco.describe()
# Out:
#        Review Date       Rating
# count  1791.000000  1795.000000
# mean   2012.321608     3.185933
# std       2.928835     0.478062
# min    2006.000000     1.000000
# 25%    2010.000000     2.875000
# 50%    2013.000000     3.250000
# 75%    2015.000000     3.500000
# max    2017.000000     5.000000

# %%
coco.head()
# Out:
#      Company  Bean Origin  Review Date Cocoa Percent Company Location  Rating
# Id
# 1   A. Morin  Agua Grande       2016.0           63%           France    3.75
# 2   A. Morin        Kpime       2015.0           70%           France    2.75
# 3   A. Morin       Atsane       2015.0           70%           France    3.00
# 4   A. Morin        Akata       2015.0           70%           France    3.50
# 5   A. Morin       Quilla       2015.0           70%           France    3.50

# %%
plt.plot(coco['Company'],coco['Company Location'],c='blue')
plt.title("coco graph")
# Out:
# Text(0.5, 1.0, 'coco graph')

# %%
import seaborn as sns
from pandas.api.types import CategoricalDtype
sns.boxplot(y=coco["Rating"])
# Out:
# <Axes: ylabel='Rating'>

# %%
coco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1795 entries, 1 to 1795
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1795 non-null   object
#  1   Bean Origin       1795 non-null   object
#  2   Review Date       1791 non-null   float64
#  3   Cocoa Percent     1795 non-null   object
#  4   Company Location  1795 non-null   object
#  5   Rating            1795 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 98.2+ KB

# %%
coco.describe()
# Out:
#        Review Date       Rating
# count  1791.000000  1795.000000
# mean   2012.321608     3.185933
# std       2.928835     0.478062
# min    2006.000000     1.000000
# 25%    2010.000000     2.875000
# 50%    2013.000000     3.250000
# 75%    2015.000000     3.500000
# max    2017.000000     5.000000

# %%
group = coco.groupby("Rating")
group.count()
coco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1795 entries, 1 to 1795
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1795 non-null   object
#  1   Bean Origin       1795 non-null   object
#  2   Review Date       1791 non-null   float64
#  3   Cocoa Percent     1795 non-null   object
#  4   Company Location  1795 non-null   object
#  5   Rating            1795 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 98.2+ KB

# %%
import numpy as np
b=[True,2,3.0,np.nan,"False"]
[type(i) for i in b]
#arr=np.array([1,2,3,4,5])#
#print(arr[::2])#
# Out:
# [bool, int, float, float, str]
